# %% [markdown]
# print("Hello World")

# %%
s = 3

# %%
t = 2

# %%
s*t
# Out:
# 6

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([3,2,5], [1,2,3])

# %%
i = 0
while i<100:
    print("infinite loop")
# Out:
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# ...

# %% [markdown]
# # Heading
# This is a text cell

# %%
sqrt(16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dfd1b01e9a51> in <module>()
# ----> 1 sqrt(16)
#
# NameError: name 'sqrt' is not defined

# %%
math.sqrt(16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-40b705a59f8e> in <module>()
# ----> 1 math.sqrt(16)
#
# NameError: name 'math' is not defined

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
x = 1
while x<10:
    print x
    x+=1
# Out:
#   File "<ipython-input-5-5196a3cbd172>", line 3
#     print x
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x)?

# %%
x = 1
while x<10:
    print(x)
    x+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
note = "Hello"
print note + "world"
# Out:
#   File "<ipython-input-7-4ef52ccfd7d8>", line 2
#     print note + "world"
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(note + "world")?

# %%
note = "Hello"
print (note + "world")
# Out:
# Helloworld

# %%
note = "Hello"
print (note + " world")
# Out:
# Hello world

# %%
print (rnd.randint(0,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2d982913ea85> in <module>()
# ----> 1 print (rnd.randint(0,100))
#
# NameError: name 'rnd' is not defined

# %%
import random
print (random.randint(0,100))
# Out:
# 23
